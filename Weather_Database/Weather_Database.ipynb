# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 778

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?" + "&appid=" + weather_api_key + "&units=imperial"

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=6cd2d2f71173067a03e8b472a71aa893&units=imperial

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_bio = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_bio,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nouadhibou
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | thurso
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hay river
# Processing Record 8 of Set 1 | chuy
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | misratah
# Processing Record 12 of Set 1 | walvis bay
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | sao filipe
# Processing Record 19 of Set 1 | lichtenburg
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | sabha
# Processing Record 22 of Set 1 | russell
# Processing Record 23 of Set 1 | simao
# Processing Record 24 of Set 1 | dinanagar
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | sao raimundo das mangabeiras
# Processing Record 28 of Set 1 | cooma
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | saint-philippe
# City not found. Skipping...
# Processing Record 35 of Set 1 | bud
# Processing Record 36 of Set 1 | mount isa
# Processing Record 37 of Set 1 | raudeberg
# Processing Record 38 of Set 1 | srednekolymsk
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | ilesha
# Processing Record 42 of Set 1 | chumikan
# Processing Record 43 of Set 1 | bannu
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | alur
# Processing Record 46 of Set 1 | tepic
# Processing Record 47 of Set 1 | goderich
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | pacific grove
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | sao joao da barra
# Processing Record 5 of Set 2 | kurumkan
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | locri
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | ostuacan
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | turukhansk
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | ullapool
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | elko
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | vetapalem
# Processing Record 25 of Set 2 | shelburne
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | eyl
# Processing Record 28 of Set 2 | illapel
# Processing Record 29 of Set 2 | bathsheba
# Processing Record 30 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 31 of Set 2 | tocopilla
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | dingle
# Processing Record 37 of Set 2 | puerto colombia
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | jeremie
# Processing Record 41 of Set 2 | sampit
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | hermon
# Processing Record 45 of Set 2 | surt
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | gamba
# Processing Record 48 of Set 2 | kyshtovka
# Processing Record 49 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 2 | kholm
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | bereznik
# Processing Record 4 of Set 3 | tambacounda
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | honiara
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 3 | kisangani
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | zhoucheng
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | rokytne
# Processing Record 15 of Set 3 | tyup
# Processing Record 16 of Set 3 | ewo
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | never
# Processing Record 19 of Set 3 | los llanos de aridane
# Processing Record 20 of Set 3 | port-gentil
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | gulfport
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | matay
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | te anau
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | moussoro
# Processing Record 29 of Set 3 | riwaka
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | verkhnyaya inta
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | hobyo
# Processing Record 34 of Set 3 | dombarovskiy
# Processing Record 35 of Set 3 | kaeo
# Processing Record 36 of Set 3 | palmer
# Processing Record 37 of Set 3 | maralal
# Processing Record 38 of Set 3 | teluknaga
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | nova olinda do norte
# Processing Record 41 of Set 3 | puerto escondido
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | ust-ordynskiy
# Processing Record 44 of Set 3 | sungairaya
# Processing Record 45 of Set 3 | las vegas
# Processing Record 46 of Set 3 | verkhnyaya tishanka
# Processing Record 47 of Set 3 | oktyabrskiy
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | melito di porto salvo
# Processing Record 50 of Set 3 | college
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | camacha
# Processing Record 3 of Set 4 | harrismith
# Processing Record 4 of Set 4 | san patricio
# Processing Record 5 of Set 4 | camana
# Processing Record 6 of Set 4 | giaveno
# Processing Record 7 of Set 4 | mandera
# Processing Record 8 of Set 4 | jidong
# Processing Record 9 of Set 4 | margate
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | fujinomiya
# Processing Record 13 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 4 | ustka
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | valparaiso
# Processing Record 18 of Set 4 | hulan
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | korla
# Processing Record 21 of Set 4 | ulaangom
# Processing Record 22 of Set 4 | wenatchee
# Processing Record 23 of Set 4 | vostok
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | guruyan
# Processing Record 26 of Set 4 | sainte-thecle
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | matoury
# Processing Record 29 of Set 4 | sivas
# Processing Record 30 of Set 4 | heihe
# Processing Record 31 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 4 | camopi
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | leshukonskoye
# Processing Record 35 of Set 4 | buzmeyin
# Processing Record 36 of Set 4 | hasaki
# Processing Record 37 of Set 4 | bainbridge
# Processing Record 38 of Set 4 | newport
# Processing Record 39 of Set 4 | tongliao
# Processing Record 40 of Set 4 | solnechnyy
# Processing Record 41 of Set 4 | zhigansk
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 44 of Set 4 | saint-pierre
# Processing Record 45 of Set 4 | rayadrug
# Processing Record 46 of Set 4 | beloha
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | gaoua
# Processing Record 49 of Set 4 | axim
# Processing Record 50 of Set 4 | san policarpo
# Processing Record 1 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 5 | pitimbu
# Processing Record 3 of Set 5 | upernavik
# Processing Record 4 of Set 5 | la palma
# Processing Record 5 of Set 5 | mont-dore
# Processing Record 6 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | west wendover
# Processing Record 9 of Set 5 | angoche
# Processing Record 10 of Set 5 | ellisras
# Processing Record 11 of Set 5 | kedrovyy
# Processing Record 12 of Set 5 | sapa
# Processing Record 13 of Set 5 | baracoa
# Processing Record 14 of Set 5 | bengkulu
# Processing Record 15 of Set 5 | sorong
# Processing Record 16 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 5 | katobu
# Processing Record 18 of Set 5 | batagay
# Processing Record 19 of Set 5 | chapais
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | novikovo
# Processing Record 24 of Set 5 | takhatpur
# Processing Record 25 of Set 5 | nagua
# Processing Record 26 of Set 5 | vuktyl
# Processing Record 27 of Set 5 | gat
# Processing Record 28 of Set 5 | bairnsdale
# Processing Record 29 of Set 5 | kampot
# Processing Record 30 of Set 5 | atambua
# Processing Record 31 of Set 5 | ladario
# Processing Record 32 of Set 5 | anadyr
# Processing Record 33 of Set 5 | teguise
# Processing Record 34 of Set 5 | ribeira grande
# Processing Record 35 of Set 5 | bontang
# Processing Record 36 of Set 5 | coquimbo
# Processing Record 37 of Set 5 | fuzhou
# Processing Record 38 of Set 5 | severo-yeniseyskiy
# Processing Record 39 of Set 5 | kalanguy
# Processing Record 40 of Set 5 | deputatskiy
# Processing Record 41 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 42 of Set 5 | kysyl-syr
# Processing Record 43 of Set 5 | baghdad
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | omsukchan
# Processing Record 46 of Set 5 | kirkuk
# Processing Record 47 of Set 5 | trincomalee
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | krugersdorp
# Processing Record 50 of Set 5 | yerbogachen
# Processing Record 1 of Set 6 | ulladulla
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | tual
# Processing Record 5 of Set 6 | loandjili
# Processing Record 6 of Set 6 | aleksandrov gay
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | oum hadjer
# Processing Record 9 of Set 6 | whitehorse
# Processing Record 10 of Set 6 | irbil
# Processing Record 11 of Set 6 | kyra
# Processing Record 12 of Set 6 | beipiao
# Processing Record 13 of Set 6 | mungaa
# Processing Record 14 of Set 6 | vila franca do campo
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | altinopolis
# Processing Record 17 of Set 6 | pacanga
# Processing Record 18 of Set 6 | myitkyina
# Processing Record 19 of Set 6 | partizanske
# Processing Record 20 of Set 6 | flin flon
# Processing Record 21 of Set 6 | ponferrada
# Processing Record 22 of Set 6 | caravelas
# Processing Record 23 of Set 6 | bjornevatn
# Processing Record 24 of Set 6 | sauda
# Processing Record 25 of Set 6 | taltal
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | niksar
# Processing Record 28 of Set 6 | ayr
# Processing Record 29 of Set 6 | mandello del lario
# Processing Record 30 of Set 6 | chimore
# Processing Record 31 of Set 6 | sindor
# Processing Record 32 of Set 6 | dekar
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | ossora
# Processing Record 35 of Set 6 | cherskiy
# Processing Record 36 of Set 6 | samarai
# Processing Record 37 of Set 6 | tiarei
# Processing Record 38 of Set 6 | chukhloma
# Processing Record 39 of Set 6 | san quintin
# Processing Record 40 of Set 6 | manjacaze
# Processing Record 41 of Set 6 | renfrew
# Processing Record 42 of Set 6 | vostochnyy
# Processing Record 43 of Set 6 | tiksi
# Processing Record 44 of Set 6 | sakakah
# Processing Record 45 of Set 6 | lucapa
# Processing Record 46 of Set 6 | namatanai
# Processing Record 47 of Set 6 | folldal
# Processing Record 48 of Set 6 | vikarabad
# Processing Record 49 of Set 6 | maningrida
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 7 | trapani
# Processing Record 3 of Set 7 | san cristobal
# Processing Record 4 of Set 7 | bonoua
# Processing Record 5 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 7 | marsa matruh
# Processing Record 7 of Set 7 | nyuksenitsa
# Processing Record 8 of Set 7 | seoul
# Processing Record 9 of Set 7 | kandrian
# Processing Record 10 of Set 7 | general escobedo
# Processing Record 11 of Set 7 | serendah
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | boralday
# Processing Record 14 of Set 7 | avera
# Processing Record 15 of Set 7 | atar
# Processing Record 16 of Set 7 | amberley
# Processing Record 17 of Set 7 | marawi
# Processing Record 18 of Set 7 | sobolevo
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | cairns
# Processing Record 21 of Set 7 | juba
# Processing Record 22 of Set 7 | pathein
# Processing Record 23 of Set 7 | weligama
# Processing Record 24 of Set 7 | odessa
# Processing Record 25 of Set 7 | devils lake
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | sao mateus do sul
# Processing Record 28 of Set 7 | sola
# Processing Record 29 of Set 7 | timizart
# Processing Record 30 of Set 7 | aklavik
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | mezen
# Processing Record 33 of Set 7 | kokopo
# Processing Record 34 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 35 of Set 7 | orange
# Processing Record 36 of Set 7 | grand gaube
# Processing Record 37 of Set 7 | khon buri
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | ponta do sol
# Processing Record 40 of Set 7 | shitkino
# Processing Record 41 of Set 7 | trofors
# Processing Record 42 of Set 7 | tabuny
# Processing Record 43 of Set 7 | anloga
# Processing Record 44 of Set 7 | corrente
# Processing Record 45 of Set 7 | saint-georges
# Processing Record 46 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 7 | constitucion
# Processing Record 49 of Set 7 | tura
# Processing Record 50 of Set 7 | ancud
# Processing Record 1 of Set 8 | riyadh
# Processing Record 2 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 8 | koungou
# Processing Record 4 of Set 8 | geraldton
# Processing Record 5 of Set 8 | kirakira
# Processing Record 6 of Set 8 | yangambi
# Processing Record 7 of Set 8 | talmenka
# Processing Record 8 of Set 8 | oranjemund
# Processing Record 9 of Set 8 | kano
# Processing Record 10 of Set 8 | jati
# Processing Record 11 of Set 8 | talaya
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | kingaroy
# Processing Record 14 of Set 8 | campana
# Processing Record 15 of Set 8 | maarianhamina
# Processing Record 16 of Set 8 | carmen
# Processing Record 17 of Set 8 | yinchuan
# Processing Record 18 of Set 8 | ugoofaaru
# Processing Record 19 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 8 | wajir
# Processing Record 21 of Set 8 | rudnogorsk
# Processing Record 22 of Set 8 | jerantut
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | partizanskoye
# Processing Record 25 of Set 8 | bone
# Processing Record 26 of Set 8 | gouyave
# Processing Record 27 of Set 8 | bilma
# Processing Record 28 of Set 8 | cidreira
# Processing Record 29 of Set 8 | hurricane
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | lewistown
# Processing Record 32 of Set 8 | dauriya
# Processing Record 33 of Set 8 | uhlove
# Processing Record 34 of Set 8 | havoysund
# Processing Record 35 of Set 8 | kalmunai
# Processing Record 36 of Set 8 | xaltianguis
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | masallatah
# Processing Record 39 of Set 8 | peniche
# Processing Record 40 of Set 8 | ayan
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | padilla
# Processing Record 43 of Set 8 | pangoa
# Processing Record 44 of Set 8 | muslyumovo
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | buraydah
# Processing Record 48 of Set 8 | tabuk
# Processing Record 49 of Set 8 | palmas
# Processing Record 50 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 9 | claveria
# Processing Record 2 of Set 9 | puma
# Processing Record 3 of Set 9 | port blair
# Processing Record 4 of Set 9 | le port
# Processing Record 5 of Set 9 | ahipara
# Processing Record 6 of Set 9 | grahamstown
# Processing Record 7 of Set 9 | scarborough
# Processing Record 8 of Set 9 | sao felix do xingu
# Processing Record 9 of Set 9 | ust-tsilma
# Processing Record 10 of Set 9 | vanimo
# Processing Record 11 of Set 9 | nhulunbuy
# Processing Record 12 of Set 9 | kurilsk
# Processing Record 13 of Set 9 | verkhoyansk
# Processing Record 14 of Set 9 | yulara
# Processing Record 15 of Set 9 | saint combs
# City not found. Skipping...
# Processing Record 16 of Set 9 | mount gambier
# Processing Record 17 of Set 9 | tessalit
# Processing Record 18 of Set 9 | mikhaylovka
# Processing Record 19 of Set 9 | tanout
# Processing Record 20 of Set 9 | ternate
# Processing Record 21 of Set 9 | karagaylinskiy
# Processing Record 22 of Set 9 | qui nhon
# Processing Record 23 of Set 9 | alofi
# Processing Record 24 of Set 9 | corinth
# Processing Record 25 of Set 9 | dongsheng
# Processing Record 26 of Set 9 | naryan-mar
# Processing Record 27 of Set 9 | kemise
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | griffith
# Processing Record 30 of Set 9 | kapoeta
# Processing Record 31 of Set 9 | makakilo city
# Processing Record 32 of Set 9 | takhtamygda
# Processing Record 33 of Set 9 | kaspiyskiy
# Processing Record 34 of Set 9 | ilek
# Processing Record 35 of Set 9 | rodrigues alves
# Processing Record 36 of Set 9 | puerto suarez
# Processing Record 37 of Set 9 | chokurdakh
# Processing Record 38 of Set 9 | katherine
# Processing Record 39 of Set 9 | andapa
# Processing Record 40 of Set 9 | kulhudhuffushi
# Processing Record 41 of Set 9 | la plata
# Processing Record 42 of Set 9 | hilton head island
# Processing Record 43 of Set 9 | bahia blanca
# Processing Record 44 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 45 of Set 9 | vereeniging
# Processing Record 46 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 9 | bolbosi
# Processing Record 48 of Set 9 | gainesville
# Processing Record 49 of Set 9 | mattru
# Processing Record 50 of Set 9 | ormond beach
# Processing Record 1 of Set 10 | sinnamary
# Processing Record 2 of Set 10 | kosa
# Processing Record 3 of Set 10 | faya
# Processing Record 4 of Set 10 | ballina
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | saint-michel-des-saints
# Processing Record 7 of Set 10 | puerto baquerizo moreno
# Processing Record 8 of Set 10 | plettenberg bay
# Processing Record 9 of Set 10 | zharkent
# Processing Record 10 of Set 10 | ostersund
# Processing Record 11 of Set 10 | camapua
# Processing Record 12 of Set 10 | linjiang
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | kindu
# Processing Record 15 of Set 10 | yongan
# Processing Record 16 of Set 10 | lithgow
# Processing Record 17 of Set 10 | srivardhan
# Processing Record 18 of Set 10 | padang
# Processing Record 19 of Set 10 | biak
# Processing Record 20 of Set 10 | aldan
# Processing Record 21 of Set 10 | dicabisagan
# Processing Record 22 of Set 10 | veere
# Processing Record 23 of Set 10 | kuleshovka
# Processing Record 24 of Set 10 | puerto cabezas
# Processing Record 25 of Set 10 | sambava
# Processing Record 26 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 10 | omboue
# Processing Record 28 of Set 10 | otukpo
# Processing Record 29 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 10 | hanna
# Processing Record 31 of Set 10 | bilibino
# Processing Record 32 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 33 of Set 10 | moree
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | guiglo
# Processing Record 36 of Set 10 | ciudad del maiz
# Processing Record 37 of Set 10 | tilichiki
# Processing Record 38 of Set 10 | rocha
# Processing Record 39 of Set 10 | conde
# Processing Record 40 of Set 10 | tigil
# Processing Record 41 of Set 10 | houma
# Processing Record 42 of Set 10 | popondetta
# Processing Record 43 of Set 10 | laguna
# Processing Record 44 of Set 10 | bouna
# Processing Record 45 of Set 10 | tiznit
# Processing Record 46 of Set 10 | gallipoli
# Processing Record 47 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 10 | kalabo
# Processing Record 49 of Set 10 | labuhan
# Processing Record 50 of Set 10 | leningradskiy
# Processing Record 1 of Set 11 | penedo
# Processing Record 2 of Set 11 | meulaboh
# Processing Record 3 of Set 11 | birjand
# Processing Record 4 of Set 11 | moerai
# Processing Record 5 of Set 11 | la asuncion
# Processing Record 6 of Set 11 | makung
# City not found. Skipping...
# Processing Record 7 of Set 11 | bushehr
# Processing Record 8 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 11 | lavrentiya
# Processing Record 10 of Set 11 | nemuro
# Processing Record 11 of Set 11 | puerto lopez
# Processing Record 12 of Set 11 | lagoa
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 11 | sumenep
# Processing Record 16 of Set 11 | mogok
# Processing Record 17 of Set 11 | nishihara
# Processing Record 18 of Set 11 | riviere-au-renard
# Processing Record 19 of Set 11 | macusani
# Processing Record 20 of Set 11 | konstantinovka
# Processing Record 21 of Set 11 | beyneu
# Processing Record 22 of Set 11 | luangwa
# Processing Record 23 of Set 11 | katsuura
# Processing Record 24 of Set 11 | ponta pora
# Processing Record 25 of Set 11 | tulun
# Processing Record 26 of Set 11 | wakkanai
# Processing Record 27 of Set 11 | ginir
# Processing Record 28 of Set 11 | cortez
# Processing Record 29 of Set 11 | the valley
# Processing Record 30 of Set 11 | maniitsoq
# Processing Record 31 of Set 11 | havelock
# Processing Record 32 of Set 11 | shamary
# Processing Record 33 of Set 11 | half moon bay
# Processing Record 34 of Set 11 | mosquera
# Processing Record 35 of Set 11 | inongo
# Processing Record 36 of Set 11 | roald
# Processing Record 37 of Set 11 | carutapera
# Processing Record 38 of Set 11 | manuk mangkaw
# Processing Record 39 of Set 11 | nanchang
# Processing Record 40 of Set 11 | kavaratti
# Processing Record 41 of Set 11 | port lincoln
# Processing Record 42 of Set 11 | yasnogorsk
# Processing Record 43 of Set 11 | chaman
# Processing Record 44 of Set 11 | uglegorsk
# Processing Record 45 of Set 11 | ankang
# Processing Record 46 of Set 11 | jos
# Processing Record 47 of Set 11 | hovd
# Processing Record 48 of Set 11 | mogadishu
# Processing Record 49 of Set 11 | osoyoos
# Processing Record 50 of Set 11 | chara
# Processing Record 1 of Set 12 | san jose
# Processing Record 2 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 12 | suntar
# Processing Record 4 of Set 12 | garmsar
# Processing Record 5 of Set 12 | nadym
# Processing Record 6 of Set 12 | soyo
# Processing Record 7 of Set 12 | kalianget
# Processing Record 8 of Set 12 | floro
# Processing Record 9 of Set 12 | moron
# Processing Record 10 of Set 12 | tarakan
# Processing Record 11 of Set 12 | carahue
# Processing Record 12 of Set 12 | likasi
# Processing Record 13 of Set 12 | tlanisco
# City not found. Skipping...
# Processing Record 14 of Set 12 | bouza
# Processing Record 15 of Set 12 | dong hoi
# Processing Record 16 of Set 12 | santa rosa
# Processing Record 17 of Set 12 | fort nelson
# Processing Record 18 of Set 12 | paamiut
# Processing Record 19 of Set 12 | lorengau
# Processing Record 20 of Set 12 | asau
# Processing Record 21 of Set 12 | vilcun
# Processing Record 22 of Set 12 | kupang
# Processing Record 23 of Set 12 | saint-joseph
# Processing Record 24 of Set 12 | mateus leme
# Processing Record 25 of Set 12 | dinhata
# Processing Record 26 of Set 12 | vendome
# Processing Record 27 of Set 12 | ilebo
# Processing Record 28 of Set 12 | estaca
# Processing Record 29 of Set 12 | auki
# Processing Record 30 of Set 12 | zyryanovskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | lazaro cardenas
# Processing Record 32 of Set 12 | simga
# Processing Record 33 of Set 12 | noshiro
# Processing Record 34 of Set 12 | tombouctou
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | koumac
# Processing Record 37 of Set 12 | talas
# Processing Record 38 of Set 12 | emmaus
# Processing Record 39 of Set 12 | bundaberg
# Processing Record 40 of Set 12 | eurajoki
# Processing Record 41 of Set 12 | hiriyur
# Processing Record 42 of Set 12 | cedral
# Processing Record 43 of Set 12 | concordia
# Processing Record 44 of Set 12 | beihai
# Processing Record 45 of Set 12 | togur
# Processing Record 46 of Set 12 | ust-kut
# Processing Record 47 of Set 12 | jalu
# Processing Record 48 of Set 12 | sao paulo de olivenca
# Processing Record 49 of Set 12 | sompeta
# Processing Record 50 of Set 12 | real
# Processing Record 1 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 13 | damavand
# Processing Record 3 of Set 13 | mineiros
# Processing Record 4 of Set 13 | frontignan
# Processing Record 5 of Set 13 | presidencia roque saenz pena
# Processing Record 6 of Set 13 | morant bay
# Processing Record 7 of Set 13 | rioja
# Processing Record 8 of Set 13 | dothan
# Processing Record 9 of Set 13 | minas
# Processing Record 10 of Set 13 | kaduqli
# Processing Record 11 of Set 13 | cruz
# Processing Record 12 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 13 | goumenissa
# Processing Record 14 of Set 13 | tautira
# Processing Record 15 of Set 13 | mbandaka
# Processing Record 16 of Set 13 | talara
# Processing Record 17 of Set 13 | antofagasta
# Processing Record 18 of Set 13 | vrangel
# Processing Record 19 of Set 13 | neuquen
# Processing Record 20 of Set 13 | vestmanna
# Processing Record 21 of Set 13 | basoko
# Processing Record 22 of Set 13 | kozhva
# Processing Record 23 of Set 13 | lovozero
# Processing Record 24 of Set 13 | okhotsk
# Processing Record 25 of Set 13 | inuvik
# Processing Record 26 of Set 13 | rehti
# Processing Record 27 of Set 13 | parana
# Processing Record 28 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 13 | boende
# Processing Record 30 of Set 13 | biltine
# Processing Record 31 of Set 13 | langenburg
# Processing Record 32 of Set 13 | saint-francois
# Processing Record 33 of Set 13 | narasannapeta
# Processing Record 34 of Set 13 | sandwick
# Processing Record 35 of Set 13 | ajdabiya
# Processing Record 36 of Set 13 | xiuyan
# Processing Record 37 of Set 13 | ouesso
# Processing Record 38 of Set 13 | iberia
# Processing Record 39 of Set 13 | kiama
# Processing Record 40 of Set 13 | kajaani
# Processing Record 41 of Set 13 | de-kastri
# Processing Record 42 of Set 13 | parys
# Processing Record 43 of Set 13 | necochea
# Processing Record 44 of Set 13 | maryborough
# Processing Record 45 of Set 13 | richards bay
# Processing Record 46 of Set 13 | borba
# Processing Record 47 of Set 13 | krasnoselkup
# Processing Record 48 of Set 13 | diu
# Processing Record 49 of Set 13 | douglas
# Processing Record 50 of Set 13 | ye
# City not found. Skipping...
# Processing Record 1 of Set 14 | ambon
# Processing Record 2 of Set 14 | el reno
# Processing Record 3 of Set 14 | cockburn town
# Processing Record 4 of Set 14 | chapada dos guimaraes
# Processing Record 5 of Set 14 | maimbung
# Processing Record 6 of Set 14 | warri
# Processing Record 7 of Set 14 | dasoguz
# Processing Record 8 of Set 14 | lukulu
# Processing Record 9 of Set 14 | ilabaya
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | gisborne
# Processing Record 12 of Set 14 | ahero
# Processing Record 13 of Set 14 | midland
# Processing Record 14 of Set 14 | manicore
# Processing Record 15 of Set 14 | gao
# Processing Record 16 of Set 14 | muscat
# Processing Record 17 of Set 14 | san-pedro
# Processing Record 18 of Set 14 | manggar
# Processing Record 19 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 21 of Set 14 | alyangula
# Processing Record 22 of Set 14 | ierapetra
# Processing Record 23 of Set 14 | chernyshevskiy
# Processing Record 24 of Set 14 | arlit
# Processing Record 25 of Set 14 | chalons-en-champagne
# Processing Record 26 of Set 14 | saint anthony
# Processing Record 27 of Set 14 | basco
# Processing Record 28 of Set 14 | lata
# Processing Record 29 of Set 14 | madang
# Processing Record 30 of Set 14 | vestmannaeyjar
# Processing Record 31 of Set 14 | bowen
# Processing Record 32 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 14 | jinchang
# Processing Record 34 of Set 14 | tahe
# Processing Record 35 of Set 14 | dondo
# Processing Record 36 of Set 14 | aktash
# Processing Record 37 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 14 | kasulu
# Processing Record 39 of Set 14 | kanniyakumari
# Processing Record 40 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 14 | campos sales
# Processing Record 42 of Set 14 | bombay
# Processing Record 43 of Set 14 | portobelo
# Processing Record 44 of Set 14 | port keats
# Processing Record 45 of Set 14 | taormina
# Processing Record 46 of Set 14 | belyy yar
# Processing Record 47 of Set 14 | katol
# Processing Record 48 of Set 14 | sechura
# Processing Record 49 of Set 14 | det udom
# Processing Record 50 of Set 14 | anaconda
# Processing Record 1 of Set 15 | nha trang
# Processing Record 2 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 15 | charters towers
# Processing Record 4 of Set 15 | tomatlan
# Processing Record 5 of Set 15 | buchanan
# Processing Record 6 of Set 15 | yarim
# Processing Record 7 of Set 15 | kununurra
# Processing Record 8 of Set 15 | fare
# Processing Record 9 of Set 15 | himora
# City not found. Skipping...
# Processing Record 10 of Set 15 | arica
# Processing Record 11 of Set 15 | sorland
# Processing Record 12 of Set 15 | caratinga
# Processing Record 13 of Set 15 | quatre cocos
# Processing Record 14 of Set 15 | kolosovka
# Processing Record 15 of Set 15 | dzhebariki-khaya
# Processing Record 16 of Set 15 | pinheiral
# Processing Record 17 of Set 15 | port angeles
# Processing Record 18 of Set 15 | portland
# Processing Record 19 of Set 15 | bairiki
# Processing Record 20 of Set 15 | keetmanshoop
# Processing Record 21 of Set 15 | broome
# Processing Record 22 of Set 15 | muravlenko
# Processing Record 23 of Set 15 | vidin
# Processing Record 24 of Set 15 | nikko
# Processing Record 25 of Set 15 | jizan
# Processing Record 26 of Set 15 | tabas
# Processing Record 27 of Set 15 | idaho falls
# Processing Record 28 of Set 15 | jay
# Processing Record 29 of Set 15 | wampusirpi
# City not found. Skipping...
# Processing Record 30 of Set 15 | huarmey
# Processing Record 31 of Set 15 | muroto
# Processing Record 32 of Set 15 | mendi
# Processing Record 33 of Set 15 | kwekwe
# Processing Record 34 of Set 15 | vysokogornyy
# City not found. Skipping...
# Processing Record 35 of Set 15 | kashi
# Processing Record 36 of Set 15 | jashpurnagar
# Processing Record 37 of Set 15 | ambovombe
# Processing Record 38 of Set 15 | haines junction
# Processing Record 39 of Set 15 | selikhino
# Processing Record 40 of Set 15 | cayenne
# Processing Record 41 of Set 15 | radovitskiy
# Processing Record 42 of Set 15 | novobirilyussy
# Processing Record 43 of Set 15 | ulaanbaatar
# Processing Record 44 of Set 15 | volot
# Processing Record 45 of Set 15 | suibara
# Processing Record 46 of Set 15 | poya
# Processing Record 47 of Set 15 | berlevag
# Processing Record 48 of Set 15 | dapaong
# Processing Record 49 of Set 15 | kamina
# Processing Record 50 of Set 15 | abashiri
# Processing Record 1 of Set 16 | nuuk
# Processing Record 2 of Set 16 | ostrovnoy
# Processing Record 3 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 16 | safaga
# Processing Record 5 of Set 16 | benjamin aceval
# Processing Record 6 of Set 16 | pitogo
# Processing Record 7 of Set 16 | quelimane
# Processing Record 8 of Set 16 | damaturu
# Processing Record 9 of Set 16 | lixourion
# Processing Record 10 of Set 16 | rovaniemi
# Processing Record 11 of Set 16 | bulaevo
# Processing Record 12 of Set 16 | carlsbad
# Processing Record 13 of Set 16 | xining
# Processing Record 14 of Set 16 | jawhar
# Processing Record 15 of Set 16 | spring hill
# Processing Record 16 of Set 16 | phalaborwa
# Processing Record 17 of Set 16 | sisimiut
# Processing Record 18 of Set 16 | lusambo
# Processing Record 19 of Set 16 | baruun-urt
# Processing Record 20 of Set 16 | dullewala
# Processing Record 21 of Set 16 | bardiyah
# Processing Record 22 of Set 16 | fatehpur
# Processing Record 23 of Set 16 | siderno
# Processing Record 24 of Set 16 | iquitos
# Processing Record 25 of Set 16 | leonforte
# Processing Record 26 of Set 16 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 27 of Set 16 | burns lake
# Processing Record 28 of Set 16 | pilar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 722

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Nouadhibou  20.9310  -17.0347     73.78        81          97       20.22
# 1    Victoria  22.2855  114.1577     88.18        77          35        5.01
# 2      Thurso  58.5927   -3.5259     48.85        84         100       11.56
# 3   Busselton -33.6500  115.3333     57.58        69          58       17.52
# 4       Bluff -46.6000  168.3333     42.80        68          94       30.85
# 5      Albany  42.6001  -73.9662     52.45        74         100        3.67
# 6   Hay River  60.8156 -115.7999     38.79        66          16        6.40
# 7        Chuy -33.6971  -53.4616     53.08        89           0        5.50
# 8   Cape Town -33.9258   18.4232     59.38        68          45        3.04
# 9    Thompson  55.7435  -97.8558     45.97        55          42        3.04
#
#   Country   Current Description                 Date
# 0      MR       overcast clouds  2022-10-05 02:11:32
# 1      HK      scattered clouds  2022-10-05 02:09:44
# 2      GB  heavy intensity rain  2022-10-05 02:11:33
# 3      AU         broken clouds  2022-10-05 02:11:28
# 4      NZ       overcast clouds  2022-10-05 02:11:34
# 5      US       overcast clouds  2022-10-05 02:10:16
# 6      CA            few clouds  2022-10-05 02:11:35
# 7      UY             clear sky  2022-10-05 02:11:36
# 8      ZA      scattered clouds  2022-10-05 02:11:37
# 9      CA      scattered clouds  2022-10-05 02:11:38

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
reordered_col = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_col]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nouadhibou      MR  20.9310  -17.0347     73.78        81          97
# 1    Victoria      HK  22.2855  114.1577     88.18        77          35
# 2      Thurso      GB  58.5927   -3.5259     48.85        84         100
# 3   Busselton      AU -33.6500  115.3333     57.58        69          58
# 4       Bluff      NZ -46.6000  168.3333     42.80        68          94
# 5      Albany      US  42.6001  -73.9662     52.45        74         100
# 6   Hay River      CA  60.8156 -115.7999     38.79        66          16
# 7        Chuy      UY -33.6971  -53.4616     53.08        89           0
# 8   Cape Town      ZA -33.9258   18.4232     59.38        68          45
# 9    Thompson      CA  55.7435  -97.8558     45.97        55          42
#
#    Wind Speed   Current Description
# 0       20.22       overcast clouds
# 1        5.01      scattered clouds
# 2       11.56  heavy intensity rain
# 3       17.52         broken clouds
# 4       30.85       overcast clouds
# 5        3.67       overcast clouds
# 6        6.40            few clouds
# 7        5.50             clear sky
# 8        3.04      scattered clouds
# 9        3.04      scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
