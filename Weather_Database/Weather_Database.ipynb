# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?" + "&appid=" + weather_api_key + "&units=imperial"

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=6cd2d2f71173067a03e8b472a71aa893&units=imperial

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_bio = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_bio,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | mingyue
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | maloy
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | salalah
# Processing Record 13 of Set 1 | bandarbeyla
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | ayan
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | mackay
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | kavieng
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | kulhudhuffushi
# Processing Record 28 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 1 | suzu
# City not found. Skipping...
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | rawson
# Processing Record 32 of Set 1 | atar
# Processing Record 33 of Set 1 | grand-lahou
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | bealanana
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | parry sound
# Processing Record 43 of Set 1 | stabat
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | skibbereen
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | nynashamn
# Processing Record 49 of Set 1 | usinsk
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | vanavara
# Processing Record 3 of Set 2 | kindu
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | oranjestad
# Processing Record 6 of Set 2 | linfen
# Processing Record 7 of Set 2 | pryozerne
# Processing Record 8 of Set 2 | udachnyy
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | deder
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | madang
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | broome
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | batticaloa
# Processing Record 21 of Set 2 | hami
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | okhotsk
# Processing Record 24 of Set 2 | sabang
# Processing Record 25 of Set 2 | padang
# Processing Record 26 of Set 2 | batemans bay
# Processing Record 27 of Set 2 | klaksvik
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | oga
# Processing Record 34 of Set 2 | bocas del toro
# Processing Record 35 of Set 2 | nemuro
# Processing Record 36 of Set 2 | bac can
# City not found. Skipping...
# Processing Record 37 of Set 2 | kailua
# Processing Record 38 of Set 2 | ejido
# Processing Record 39 of Set 2 | saint-francois
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 42 of Set 2 | kenai
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 2 | lavrentiya
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | praia da vitoria
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | manono
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | benghazi
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | lakatoro
# Processing Record 4 of Set 3 | tautira
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | khasan
# Processing Record 8 of Set 3 | aanekoski
# Processing Record 9 of Set 3 | malakal
# Processing Record 10 of Set 3 | bafia
# Processing Record 11 of Set 3 | zhucheng
# Processing Record 12 of Set 3 | abu dhabi
# Processing Record 13 of Set 3 | abatskoye
# Processing Record 14 of Set 3 | kiama
# Processing Record 15 of Set 3 | hay river
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | inhambane
# Processing Record 18 of Set 3 | inuvik
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | marzuq
# Processing Record 24 of Set 3 | grindavik
# Processing Record 25 of Set 3 | xiongzhou
# Processing Record 26 of Set 3 | iranshahr
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | arraial do cabo
# Processing Record 29 of Set 3 | ewa beach
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | geraldton
# Processing Record 34 of Set 3 | mwene-ditu
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | kuryk
# Processing Record 37 of Set 3 | chimbote
# Processing Record 38 of Set 3 | san pedro
# Processing Record 39 of Set 3 | drovyanaya
# Processing Record 40 of Set 3 | asau
# Processing Record 41 of Set 3 | porto novo
# Processing Record 42 of Set 3 | soyo
# Processing Record 43 of Set 3 | puerto escondido
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | bathsheba
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | shetpe
# Processing Record 48 of Set 3 | middelburg
# Processing Record 49 of Set 3 | vyazemskiy
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | belaya gora
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | birao
# Processing Record 5 of Set 4 | cherskiy
# Processing Record 6 of Set 4 | ostrovnoy
# Processing Record 7 of Set 4 | tahara
# Processing Record 8 of Set 4 | port keats
# Processing Record 9 of Set 4 | narasannapeta
# Processing Record 10 of Set 4 | necochea
# Processing Record 11 of Set 4 | santa cruz de tenerife
# Processing Record 12 of Set 4 | hambantota
# Processing Record 13 of Set 4 | mosetse
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | soe
# Processing Record 16 of Set 4 | tual
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | vila velha
# Processing Record 19 of Set 4 | nantucket
# Processing Record 20 of Set 4 | kavaratti
# Processing Record 21 of Set 4 | bor
# Processing Record 22 of Set 4 | port blair
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | tuatapere
# Processing Record 25 of Set 4 | acapulco
# Processing Record 26 of Set 4 | bridlington
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | waipawa
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | lewistown
# Processing Record 35 of Set 4 | haines junction
# Processing Record 36 of Set 4 | west bay
# Processing Record 37 of Set 4 | alta floresta
# Processing Record 38 of Set 4 | kilis
# Processing Record 39 of Set 4 | dudinka
# Processing Record 40 of Set 4 | sao filipe
# Processing Record 41 of Set 4 | vila franca do campo
# Processing Record 42 of Set 4 | mount gambier
# Processing Record 43 of Set 4 | cam ranh
# Processing Record 44 of Set 4 | orange
# Processing Record 45 of Set 4 | teguise
# Processing Record 46 of Set 4 | the valley
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | jumla
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | waitati
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | ternate
# Processing Record 4 of Set 5 | hermanus
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | redmond
# Processing Record 7 of Set 5 | portland
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 5 | chegdomyn
# Processing Record 12 of Set 5 | batagay-alyta
# Processing Record 13 of Set 5 | nkawkaw
# Processing Record 14 of Set 5 | mlimba
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | berezovyy
# Processing Record 17 of Set 5 | freeport
# Processing Record 18 of Set 5 | erenhot
# Processing Record 19 of Set 5 | flinders
# Processing Record 20 of Set 5 | sungairaya
# Processing Record 21 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 5 | quatre cocos
# Processing Record 23 of Set 5 | yellowknife
# Processing Record 24 of Set 5 | oistins
# Processing Record 25 of Set 5 | jalu
# Processing Record 26 of Set 5 | hobart
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | opochka
# Processing Record 29 of Set 5 | kaharlyk
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | aden
# Processing Record 33 of Set 5 | saint anthony
# Processing Record 34 of Set 5 | jinchang
# Processing Record 35 of Set 5 | auki
# Processing Record 36 of Set 5 | dire dawa
# Processing Record 37 of Set 5 | najran
# Processing Record 38 of Set 5 | shintomi
# Processing Record 39 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 5 | ampanihy
# Processing Record 41 of Set 5 | havre-saint-pierre
# Processing Record 42 of Set 5 | voykove
# Processing Record 43 of Set 5 | dunedin
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | bethlehem
# Processing Record 47 of Set 5 | mokhsogollokh
# Processing Record 48 of Set 5 | beian
# Processing Record 49 of Set 5 | talah
# City not found. Skipping...
# Processing Record 50 of Set 5 | blind river
# Processing Record 1 of Set 6 | barrow
# Processing Record 2 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | zonguldak
# Processing Record 5 of Set 6 | samarai
# Processing Record 6 of Set 6 | college
# Processing Record 7 of Set 6 | hualmay
# Processing Record 8 of Set 6 | carnarvon
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | grinnell
# Processing Record 11 of Set 6 | smithers
# Processing Record 12 of Set 6 | svetlyy
# Processing Record 13 of Set 6 | lavumisa
# Processing Record 14 of Set 6 | havoysund
# Processing Record 15 of Set 6 | alyangula
# Processing Record 16 of Set 6 | itaituba
# Processing Record 17 of Set 6 | te anau
# Processing Record 18 of Set 6 | palatka
# Processing Record 19 of Set 6 | christchurch
# Processing Record 20 of Set 6 | jishou
# Processing Record 21 of Set 6 | naron
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | shenjiamen
# Processing Record 24 of Set 6 | montemor-o-novo
# Processing Record 25 of Set 6 | mizan teferi
# Processing Record 26 of Set 6 | katherine
# Processing Record 27 of Set 6 | eureka
# Processing Record 28 of Set 6 | yurla
# Processing Record 29 of Set 6 | skeldon
# Processing Record 30 of Set 6 | aquiraz
# Processing Record 31 of Set 6 | ola
# Processing Record 32 of Set 6 | barabinsk
# Processing Record 33 of Set 6 | matagami
# Processing Record 34 of Set 6 | araruna
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | polunochnoye
# Processing Record 37 of Set 6 | isla mujeres
# Processing Record 38 of Set 6 | puerto ayora
# Processing Record 39 of Set 6 | chancay
# Processing Record 40 of Set 6 | lakota
# Processing Record 41 of Set 6 | caravelas
# Processing Record 42 of Set 6 | nauchnyy gorodok
# Processing Record 43 of Set 6 | brazzaville
# Processing Record 44 of Set 6 | changping
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | plettenberg bay
# Processing Record 48 of Set 6 | taltal
# Processing Record 49 of Set 6 | port hardy
# Processing Record 50 of Set 6 | winthrop
# Processing Record 1 of Set 7 | anjiang
# Processing Record 2 of Set 7 | la reforma
# Processing Record 3 of Set 7 | upernavik
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | duz
# City not found. Skipping...
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | kiyasovo
# Processing Record 8 of Set 7 | alim
# Processing Record 9 of Set 7 | lincolnton
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | qandala
# Processing Record 12 of Set 7 | chumikan
# Processing Record 13 of Set 7 | batagay
# Processing Record 14 of Set 7 | black river
# Processing Record 15 of Set 7 | chichigalpa
# Processing Record 16 of Set 7 | narrabri
# Processing Record 17 of Set 7 | nanakuli
# Processing Record 18 of Set 7 | dekar
# Processing Record 19 of Set 7 | airai
# Processing Record 20 of Set 7 | hovd
# Processing Record 21 of Set 7 | san isidro
# Processing Record 22 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 7 | killybegs
# Processing Record 24 of Set 7 | danilovka
# Processing Record 25 of Set 7 | mahdalynivka
# Processing Record 26 of Set 7 | log
# Processing Record 27 of Set 7 | voi
# Processing Record 28 of Set 7 | okha
# Processing Record 29 of Set 7 | gizo
# Processing Record 30 of Set 7 | ponta do sol
# Processing Record 31 of Set 7 | grand gaube
# Processing Record 32 of Set 7 | sakakah
# Processing Record 33 of Set 7 | santa marta
# Processing Record 34 of Set 7 | lafiagi
# Processing Record 35 of Set 7 | neya
# Processing Record 36 of Set 7 | ribas do rio pardo
# Processing Record 37 of Set 7 | surt
# Processing Record 38 of Set 7 | sena madureira
# Processing Record 39 of Set 7 | akdepe
# Processing Record 40 of Set 7 | tomohon
# Processing Record 41 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 7 | vila
# Processing Record 43 of Set 7 | sobolevo
# Processing Record 44 of Set 7 | taoudenni
# Processing Record 45 of Set 7 | cheyur
# City not found. Skipping...
# Processing Record 46 of Set 7 | saint-pierre
# Processing Record 47 of Set 7 | emerald
# Processing Record 48 of Set 7 | comodoro rivadavia
# Processing Record 49 of Set 7 | lorengau
# Processing Record 50 of Set 7 | carbonear
# Processing Record 1 of Set 8 | birobidzhan
# Processing Record 2 of Set 8 | moose factory
# Processing Record 3 of Set 8 | nhulunbuy
# Processing Record 4 of Set 8 | lahad datu
# Processing Record 5 of Set 8 | kirakira
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | kaitong
# Processing Record 9 of Set 8 | mozarlandia
# Processing Record 10 of Set 8 | darnah
# Processing Record 11 of Set 8 | tupik
# Processing Record 12 of Set 8 | roald
# Processing Record 13 of Set 8 | yatou
# Processing Record 14 of Set 8 | kysyl-syr
# Processing Record 15 of Set 8 | ibra
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | marawi
# Processing Record 18 of Set 8 | russellville
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | victor harbor
# Processing Record 21 of Set 8 | nishihara
# Processing Record 22 of Set 8 | ushtobe
# Processing Record 23 of Set 8 | itarema
# Processing Record 24 of Set 8 | fare
# Processing Record 25 of Set 8 | bonavista
# Processing Record 26 of Set 8 | bardiyah
# Processing Record 27 of Set 8 | baykit
# Processing Record 28 of Set 8 | ornskoldsvik
# Processing Record 29 of Set 8 | edd
# Processing Record 30 of Set 8 | biak
# Processing Record 31 of Set 8 | lewisporte
# Processing Record 32 of Set 8 | tashtagol
# Processing Record 33 of Set 8 | etchojoa
# Processing Record 34 of Set 8 | nouadhibou
# Processing Record 35 of Set 8 | rongcheng
# Processing Record 36 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 8 | agadez
# Processing Record 38 of Set 8 | morondava
# Processing Record 39 of Set 8 | catalina foothills
# Processing Record 40 of Set 8 | sosnovo-ozerskoye
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | kashi
# Processing Record 43 of Set 8 | almaznyy
# Processing Record 44 of Set 8 | seoul
# Processing Record 45 of Set 8 | sioux lookout
# Processing Record 46 of Set 8 | nyurba
# Processing Record 47 of Set 8 | carahue
# Processing Record 48 of Set 8 | zhangjiakou
# Processing Record 49 of Set 8 | natchitoches
# Processing Record 50 of Set 8 | bilibino
# Processing Record 1 of Set 9 | nuevo progreso
# Processing Record 2 of Set 9 | villeta
# Processing Record 3 of Set 9 | filingue
# Processing Record 4 of Set 9 | puerto rondon
# Processing Record 5 of Set 9 | bilma
# Processing Record 6 of Set 9 | thaton
# Processing Record 7 of Set 9 | messina
# Processing Record 8 of Set 9 | takanosu
# Processing Record 9 of Set 9 | weinan
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | buckeye
# Processing Record 12 of Set 9 | lao cai
# Processing Record 13 of Set 9 | nanortalik
# Processing Record 14 of Set 9 | kununurra
# Processing Record 15 of Set 9 | conway
# Processing Record 16 of Set 9 | muswellbrook
# Processing Record 17 of Set 9 | marsh harbour
# Processing Record 18 of Set 9 | pajan
# Processing Record 19 of Set 9 | barcelona
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | digras
# Processing Record 22 of Set 9 | thinadhoo
# Processing Record 23 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 9 | meulaboh
# Processing Record 25 of Set 9 | luanda
# Processing Record 26 of Set 9 | pathri
# Processing Record 27 of Set 9 | nevel
# Processing Record 28 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 9 | ponta delgada
# Processing Record 30 of Set 9 | avera
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | pacific grove
# Processing Record 33 of Set 9 | marsa matruh
# Processing Record 34 of Set 9 | aykhal
# Processing Record 35 of Set 9 | port macquarie
# Processing Record 36 of Set 9 | ried
# Processing Record 37 of Set 9 | phuket
# Processing Record 38 of Set 9 | prince george
# Processing Record 39 of Set 9 | zaraza
# Processing Record 40 of Set 9 | bhinmal
# Processing Record 41 of Set 9 | krasnoarmeysk
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | coihaique
# Processing Record 44 of Set 9 | ures
# Processing Record 45 of Set 9 | springbok
# Processing Record 46 of Set 9 | ouallam
# Processing Record 47 of Set 9 | forbes
# Processing Record 48 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 49 of Set 9 | matehuala
# Processing Record 50 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 10 | cancun
# Processing Record 2 of Set 10 | killarney
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | pangai
# Processing Record 5 of Set 10 | tokmak
# Processing Record 6 of Set 10 | folldal
# Processing Record 7 of Set 10 | darhan
# Processing Record 8 of Set 10 | khilok
# Processing Record 9 of Set 10 | yingkou
# Processing Record 10 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 10 | fortuna foothills
# Processing Record 12 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | gorontalo
# Processing Record 14 of Set 10 | quang ngai
# Processing Record 15 of Set 10 | coahuayana
# Processing Record 16 of Set 10 | pasighat
# Processing Record 17 of Set 10 | nieuwpoort
# Processing Record 18 of Set 10 | holme
# Processing Record 19 of Set 10 | alamosa
# Processing Record 20 of Set 10 | paamiut
# Processing Record 21 of Set 10 | nouakchott
# Processing Record 22 of Set 10 | abha
# Processing Record 23 of Set 10 | babocsa
# Processing Record 24 of Set 10 | stornoway
# Processing Record 25 of Set 10 | berbera
# Processing Record 26 of Set 10 | north platte
# Processing Record 27 of Set 10 | ketchikan
# Processing Record 28 of Set 10 | la ronge
# Processing Record 29 of Set 10 | maple creek
# Processing Record 30 of Set 10 | bonthe
# Processing Record 31 of Set 10 | show low
# Processing Record 32 of Set 10 | port lavaca
# Processing Record 33 of Set 10 | bombay
# Processing Record 34 of Set 10 | narsaq
# Processing Record 35 of Set 10 | dabola
# Processing Record 36 of Set 10 | yulara
# Processing Record 37 of Set 10 | mana
# Processing Record 38 of Set 10 | yar-sale
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | tillabery
# City not found. Skipping...
# Processing Record 41 of Set 10 | bikaner
# Processing Record 42 of Set 10 | rafaela
# Processing Record 43 of Set 10 | kyaikto
# Processing Record 44 of Set 10 | wum
# Processing Record 45 of Set 10 | christiana
# Processing Record 46 of Set 10 | puerto madryn
# Processing Record 47 of Set 10 | wagar
# Processing Record 48 of Set 10 | ugoofaaru
# Processing Record 49 of Set 10 | pangnirtung
# Processing Record 50 of Set 10 | rock sound
# Processing Record 1 of Set 11 | huarmey
# Processing Record 2 of Set 11 | karoi
# Processing Record 3 of Set 11 | iracoubo
# Processing Record 4 of Set 11 | gari
# Processing Record 5 of Set 11 | liwale
# Processing Record 6 of Set 11 | port pirie
# Processing Record 7 of Set 11 | alto araguaia
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | olafsvik
# Processing Record 10 of Set 11 | los llanos de aridane
# Processing Record 11 of Set 11 | laukaa
# Processing Record 12 of Set 11 | venafro
# Processing Record 13 of Set 11 | badulla
# Processing Record 14 of Set 11 | hamilton
# Processing Record 15 of Set 11 | gonbad-e qabus
# Processing Record 16 of Set 11 | robertsport
# Processing Record 17 of Set 11 | banjar
# Processing Record 18 of Set 11 | san rafael
# Processing Record 19 of Set 11 | koson
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | jizan
# Processing Record 22 of Set 11 | trincomalee
# Processing Record 23 of Set 11 | sumter
# Processing Record 24 of Set 11 | andenes
# Processing Record 25 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 11 | alofi
# Processing Record 27 of Set 11 | clovis
# Processing Record 28 of Set 11 | mayo
# Processing Record 29 of Set 11 | tiznit
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | zyryanka
# Processing Record 32 of Set 11 | thap than
# Processing Record 33 of Set 11 | juazeiro
# Processing Record 34 of Set 11 | southbridge
# Processing Record 35 of Set 11 | port-gentil
# Processing Record 36 of Set 11 | esso
# Processing Record 37 of Set 11 | gushikawa
# Processing Record 38 of Set 11 | walvis bay
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | mabaruma
# Processing Record 41 of Set 11 | cuamba
# Processing Record 42 of Set 11 | adrar
# Processing Record 43 of Set 11 | chimoio
# Processing Record 44 of Set 11 | porbandar
# Processing Record 45 of Set 11 | progreso
# Processing Record 46 of Set 11 | verkhnevilyuysk
# Processing Record 47 of Set 11 | point pedro
# Processing Record 48 of Set 11 | ilorin
# Processing Record 49 of Set 11 | ulundi
# Processing Record 50 of Set 11 | balykshi
# Processing Record 1 of Set 12 | lhokseumawe
# Processing Record 2 of Set 12 | sola
# Processing Record 3 of Set 12 | devils lake
# Processing Record 4 of Set 12 | hamadan
# Processing Record 5 of Set 12 | ajaccio
# Processing Record 6 of Set 12 | baiyin
# Processing Record 7 of Set 12 | teknaf
# Processing Record 8 of Set 12 | bogande
# Processing Record 9 of Set 12 | beringovskiy
# Processing Record 10 of Set 12 | puerto maldonado
# Processing Record 11 of Set 12 | kpandae
# Processing Record 12 of Set 12 | mathathane
# Processing Record 13 of Set 12 | bosaso
# Processing Record 14 of Set 12 | ulaangom
# Processing Record 15 of Set 12 | xiaoweizhai
# Processing Record 16 of Set 12 | wladyslawowo
# Processing Record 17 of Set 12 | cabatuan
# Processing Record 18 of Set 12 | abengourou
# Processing Record 19 of Set 12 | bolotnoye
# Processing Record 20 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 12 | maningrida
# Processing Record 22 of Set 12 | palencia
# Processing Record 23 of Set 12 | xiangdong
# City not found. Skipping...
# Processing Record 24 of Set 12 | superior
# Processing Record 25 of Set 12 | bud
# Processing Record 26 of Set 12 | aksu
# Processing Record 27 of Set 12 | gat
# Processing Record 28 of Set 12 | manta
# Processing Record 29 of Set 12 | laguna
# Processing Record 30 of Set 12 | khorixas
# Processing Record 31 of Set 12 | alugan
# Processing Record 32 of Set 12 | sisimiut
# Processing Record 33 of Set 12 | korem
# Processing Record 34 of Set 12 | ilhabela
# Processing Record 35 of Set 12 | belen
# Processing Record 36 of Set 12 | doka
# Processing Record 37 of Set 12 | almeirim
# Processing Record 38 of Set 12 | santa isabel do rio negro
# Processing Record 39 of Set 12 | awjilah
# Processing Record 40 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 12 | butterworth
# Processing Record 43 of Set 12 | dubbo
# Processing Record 44 of Set 12 | santa maria
# Processing Record 45 of Set 12 | doctor cecilio baez
# Processing Record 46 of Set 12 | machico
# Processing Record 47 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 12 | awbari
# Processing Record 49 of Set 12 | snasa
# Processing Record 50 of Set 12 | llandrindod wells
# Processing Record 1 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 2 of Set 13 | conceicao do araguaia
# Processing Record 3 of Set 13 | rosetta
# Processing Record 4 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 13 | ha giang
# Processing Record 6 of Set 13 | chunhuhub
# Processing Record 7 of Set 13 | carbondale
# Processing Record 8 of Set 13 | vostok
# Processing Record 9 of Set 13 | berkak
# Processing Record 10 of Set 13 | melo
# Processing Record 11 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 13 | bambanglipuro
# Processing Record 13 of Set 13 | ranong
# Processing Record 14 of Set 13 | teluknaga
# Processing Record 15 of Set 13 | caxito
# Processing Record 16 of Set 13 | correntina
# Processing Record 17 of Set 13 | praia
# Processing Record 18 of Set 13 | pochutla
# Processing Record 19 of Set 13 | iquitos
# Processing Record 20 of Set 13 | kamina
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 23 of Set 13 | arak
# Processing Record 24 of Set 13 | kaoma
# Processing Record 25 of Set 13 | guiratinga
# Processing Record 26 of Set 13 | san carlos de bariloche
# Processing Record 27 of Set 13 | namatanai
# Processing Record 28 of Set 13 | misratah
# Processing Record 29 of Set 13 | mombetsu
# Processing Record 30 of Set 13 | mehamn
# Processing Record 31 of Set 13 | ossora
# Processing Record 32 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 33 of Set 13 | porosozero
# Processing Record 34 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 13 | afyonkarahisar
# Processing Record 36 of Set 13 | sao felix do xingu
# Processing Record 37 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 38 of Set 13 | tadine
# Processing Record 39 of Set 13 | borogontsy
# Processing Record 40 of Set 13 | ust-maya
# Processing Record 41 of Set 13 | raudeberg
# Processing Record 42 of Set 13 | honningsvag
# Processing Record 43 of Set 13 | dajal
# Processing Record 44 of Set 13 | jeremie
# Processing Record 45 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 46 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 13 | los andes
# Processing Record 48 of Set 13 | parrita
# Processing Record 49 of Set 13 | guanica
# Processing Record 50 of Set 13 | hoquiam
# Processing Record 1 of Set 14 | khor
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | panama city
# Processing Record 4 of Set 14 | eydhafushi
# Processing Record 5 of Set 14 | chulman
# Processing Record 6 of Set 14 | sampit
# Processing Record 7 of Set 14 | mount isa
# Processing Record 8 of Set 14 | pervomayskoye
# Processing Record 9 of Set 14 | palmas de monte alto
# Processing Record 10 of Set 14 | vanimo
# Processing Record 11 of Set 14 | cordele
# Processing Record 12 of Set 14 | kupang
# Processing Record 13 of Set 14 | claremore
# Processing Record 14 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 14 | tateyama
# Processing Record 16 of Set 14 | margate
# Processing Record 17 of Set 14 | osmena
# Processing Record 18 of Set 14 | eenhana
# Processing Record 19 of Set 14 | manicore
# Processing Record 20 of Set 14 | altagracia de orituco
# Processing Record 21 of Set 14 | catamarca
# Processing Record 22 of Set 14 | ereymentau
# Processing Record 23 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 14 | arani
# Processing Record 25 of Set 14 | taganak
# Processing Record 26 of Set 14 | bani
# Processing Record 27 of Set 14 | codajas
# Processing Record 28 of Set 14 | nosy varika
# Processing Record 29 of Set 14 | partenit
# Processing Record 30 of Set 14 | karratha
# Processing Record 31 of Set 14 | bousso
# Processing Record 32 of Set 14 | verkhnyaya sinyachikha
# Processing Record 33 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 34 of Set 14 | channel-port aux basques
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | boyolangu
# Processing Record 37 of Set 14 | deputatskiy
# Processing Record 38 of Set 14 | chiredzi
# Processing Record 39 of Set 14 | yuzhno-kurilsk
# Processing Record 40 of Set 14 | gollere
# City not found. Skipping...
# Processing Record 41 of Set 14 | vao
# Processing Record 42 of Set 14 | dong hoi
# Processing Record 43 of Set 14 | kabansk
# Processing Record 44 of Set 14 | arlit
# Processing Record 45 of Set 14 | altay
# Processing Record 46 of Set 14 | arman
# Processing Record 47 of Set 14 | namibe
# Processing Record 48 of Set 14 | kushima
# Processing Record 49 of Set 14 | hebertville
# City not found. Skipping...
# Processing Record 50 of Set 14 | makakilo city
# Processing Record 1 of Set 15 | naenwa
# City not found. Skipping...
# Processing Record 2 of Set 15 | zunheboto
# Processing Record 3 of Set 15 | ukiah
# Processing Record 4 of Set 15 | la palma
# Processing Record 5 of Set 15 | aviles
# Processing Record 6 of Set 15 | puerto quijarro
# Processing Record 7 of Set 15 | caraballeda
# Processing Record 8 of Set 15 | mae ramat
# Processing Record 9 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 10 of Set 15 | phan thiet
# Processing Record 11 of Set 15 | americus
# Processing Record 12 of Set 15 | bayir
# Processing Record 13 of Set 15 | madingou
# Processing Record 14 of Set 15 | cap-aux-meules
# Processing Record 15 of Set 15 | lucea
# Processing Record 16 of Set 15 | dhemaji
# Processing Record 17 of Set 15 | juntas
# Processing Record 18 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 15 | gol
# Processing Record 20 of Set 15 | benguela
# Processing Record 21 of Set 15 | uchaly
# Processing Record 22 of Set 15 | half moon bay
# Processing Record 23 of Set 15 | fairbanks
# Processing Record 24 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 15 | laguna de perlas
# Processing Record 26 of Set 15 | vaimela
# City not found. Skipping...
# Processing Record 27 of Set 15 | tezu
# Processing Record 28 of Set 15 | jiangyou
# Processing Record 29 of Set 15 | natal
# Processing Record 30 of Set 15 | lermontovka
# Processing Record 31 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 15 | ulladulla
# Processing Record 33 of Set 15 | guadalupe y calvo
# Processing Record 34 of Set 15 | red bank
# Processing Record 35 of Set 15 | yichun
# Processing Record 36 of Set 15 | yarada
# Processing Record 37 of Set 15 | mitsamiouli
# Processing Record 38 of Set 15 | solnechnyy
# Processing Record 39 of Set 15 | mogadishu
# Processing Record 40 of Set 15 | kudahuvadhoo
# Processing Record 41 of Set 15 | anahuac
# Processing Record 42 of Set 15 | parchim
# Processing Record 43 of Set 15 | straumen
# Processing Record 44 of Set 15 | fayaoue
# Processing Record 45 of Set 15 | tessalit
# Processing Record 46 of Set 15 | miramar
# Processing Record 47 of Set 15 | lufilufi
# Processing Record 48 of Set 15 | turukhansk
# Processing Record 49 of Set 15 | beloha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mahebourg -20.4081   57.7000     70.25        78          20
# 1       Mingyue  43.1069  128.9217     43.03        55           5
# 2        Albany  42.6001  -73.9662     49.68        78         100
# 3        Kodiak  57.7900 -152.4072     51.31        82         100
# 4      Katsuura  35.1333  140.3000     77.20        70          73
# 5        Castro -24.7911  -50.0119     56.52        97         100
# 6         Maloy  61.9353    5.1136     54.73        62         100
# 7  Saint George  37.1041 -113.5841     79.39        31           0
# 8       Salalah  17.0151   54.0924     75.29        88          75
# 9   Bandarbeyla   9.4942   50.8122     76.87        77          26
#
#    Wind Speed Country Current Description                 Date
# 0        6.91      MU          few clouds  2022-10-04 01:25:32
# 1        8.43      CN           clear sky  2022-10-04 01:25:33
# 2        1.88      US     overcast clouds  2022-10-04 01:25:34
# 3        8.05      US                haze  2022-10-04 01:19:04
# 4       19.28      JP       broken clouds  2022-10-04 01:24:35
# 5        4.27      BR     overcast clouds  2022-10-04 01:22:07
# 6       14.74      NO          light rain  2022-10-04 01:25:36
# 7       13.80      US           clear sky  2022-10-04 01:22:58
# 8        2.30      OM       broken clouds  2022-10-04 01:25:37
# 9       21.52      SO    scattered clouds  2022-10-04 01:25:38

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
reordered_col = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_col]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mahebourg      MU -20.4081   57.7000     70.25        78          20
# 1       Mingyue      CN  43.1069  128.9217     43.03        55           5
# 2        Albany      US  42.6001  -73.9662     49.68        78         100
# 3        Kodiak      US  57.7900 -152.4072     51.31        82         100
# 4      Katsuura      JP  35.1333  140.3000     77.20        70          73
# 5        Castro      BR -24.7911  -50.0119     56.52        97         100
# 6         Maloy      NO  61.9353    5.1136     54.73        62         100
# 7  Saint George      US  37.1041 -113.5841     79.39        31           0
# 8       Salalah      OM  17.0151   54.0924     75.29        88          75
# 9   Bandarbeyla      SO   9.4942   50.8122     76.87        77          26
#
#    Wind Speed Current Description
# 0        6.91          few clouds
# 1        8.43           clear sky
# 2        1.88     overcast clouds
# 3        8.05                haze
# 4       19.28       broken clouds
# 5        4.27     overcast clouds
# 6       14.74          light rain
# 7       13.80           clear sky
# 8        2.30       broken clouds
# 9       21.52    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
